# %% [markdown]
# ![Screenshot.png](data:image/png;base64,...)

# %%
text = input("write a sentence: ")

a = 0
b={}

for i in text:
  c = {text[a]: text.count(i)}
  b.update(c)
  a += 1
  
print(b, end="")
# Out:
# write a sentence: hippo runs to us!
# {'h': 1, 'i': 1, 'p': 2, 'o': 2, ' ': 3, 'r': 1, 'u': 2, 'n': 1, 's': 2, 't': 1, '!': 1}
